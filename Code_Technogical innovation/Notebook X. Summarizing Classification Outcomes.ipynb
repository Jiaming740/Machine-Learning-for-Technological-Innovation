# %% [markdown]
# # **Notebook X.** Summarizing Classification Outcomes
# ----

# %% [markdown]
# In  the earlier notebooks we have tested different classification models.
#
# Here, we provide a comparison of all of the models as well as an in-depth analysis of the "best performing" model.

# %% [markdown]
# # X.1. Preamble: Load Packages
# ---

# %%
# General Packages #
import os
import pandas as pd
import numpy as np

# Load TQDM to Show Progress Bars #
from tqdm import tqdm
from tqdm.notebook import tqdm as tqdm_notebook

# Sklearn Packages #
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report

from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Turn of warnings, just to avoid pesky messages that might cause confusion here
# Remove when testing your own code #
import warnings
warnings.filterwarnings("ignore")

# %%
# Mount Personal Google Drive on own Machine -- You have to follow the link to log in #
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # X.2. Compare Classification Results ##
# ----------------
#
# We have saved our model classification results in Google Drive. Here, we are going to compare the different classification results.

# %%
# Change to Working Directory with Training Data #
os.chdir("/content/drive/MyDrive/Power-data-main/")

Counter = 0
for root, dirs, files in os.walk("./Output/Model Performance/"):
  for file in files:
    temp = pd.read_csv("./Output/Model Performance/" + file)
    if Counter == 0:
      Combined = temp
    else:
      Combined = pd.concat([Combined, temp])
    Counter = Counter + 1

# %%
# See the Ouptut with All Models #

Combined.drop("Unnamed: 0", axis = 1).sort_values("Accuracy", ascending = False)
# Out:
#                                Name               Type  Share  True-Positives  \
# 0                   XLNet (Chinese)        Transformer  0.423           0.927
# 1                BERT-wwm (Chinese)        Transformer  0.438           0.909
# 3                    BERT (Chinese)        Transformer  0.441           0.904
# 2                 ELECTRA (Chinese)        Transformer  0.432           0.911
# 0            Multi Layer Perceptron  Embedding Vectors  0.436           0.898
# 4                 MacBERT (Chinese)        Transformer  0.445           0.891
# 1   Support Vector Classifier (RBF)  Embedding Vectors  0.450           0.879
# 0                     Random Forest       Bag of Words  0.444           0.882
# 1   Support Vector Classifier (RBF)       Bag of Words  0.425           0.898
# 0               Power data Word2Vec                CNN  0.460           0.861
# 2               Logistic Regression       Bag of Words  0.438           0.880
# 2                     Random Forest  Embedding Vectors  0.423           0.891
# 3      Gradient Boosting Classifier  Embedding Vectors  0.442           0.873
# 4               Logistic Regression  Embedding Vectors  0.445           0.870
# 3                             LASSO       Bag of Words  0.431           0.879
# 4                  Ridge Regression       Bag of Words  0.437           0.871
# 6                             LASSO  Embedding Vectors  0.460           0.852
# 5                  Ridge Regression  Embedding Vectors  0.458           0.854
# 1                  Chinese Word2Vec                CNN  0.435           0.871
# 2                          FastText                CNN  0.418           0.886
# 7                 Linear Regression  Embedding Vectors  0.458           0.852
# 5                 RoBERTa (Chinese)        Transformer  0.401           0.900
# 5      Gradient Boosting Classifier       Bag of Words  0.418           0.880
# 8                 Robust Regression  Embedding Vectors  0.476           0.831
# 6            Multi Layer Perceptron       Bag of Words  0.433           0.858
# 7        Decision Tree with Bagging       Bag of Words  0.412           0.875
# 9       Decision Tree with Boosting  Embedding Vectors  0.451           0.841
# 11       Decision Tree with Bagging  Embedding Vectors  0.404           0.878
# 10                Nearest Neighbors  Embedding Vectors  0.498           0.807
# 8       Decision Tree with Boosting       Bag of Words  0.433           0.850
# 9                 Robust Regression       Bag of Words  0.440           0.844
# 10                      Naive Bayes       Bag of Words  0.500           0.792
# 11                Linear Regression       Bag of Words  0.445           0.812
# 3                     No Embeddings                CNN  0.482           0.788
# 12                Nearest Neighbors       Bag of Words  0.344           0.877
#
#     False-Negatives  False-Positives  True-Negatives  Accuracy    AUC  \
# 0             0.936            0.073           0.064     0.932  0.930
# 1             0.944            0.091           0.056     0.928  0.928
# 3             0.945            0.096           0.055     0.927  0.927
# 2             0.938            0.089           0.062     0.927  0.926
# 0             0.935            0.102           0.065     0.919  0.918
# 4             0.941            0.109           0.059     0.919  0.920
# 1             0.940            0.121           0.060     0.913  0.914
# 0             0.932            0.118           0.068     0.910  0.910
# 1             0.918            0.102           0.082     0.909  0.907
# 0             0.940            0.139           0.060     0.904  0.906
# 2             0.922            0.120           0.078     0.904  0.903
# 2             0.910            0.109           0.090     0.902  0.899
# 3             0.923            0.127           0.077     0.901  0.901
# 4             0.924            0.130           0.076     0.900  0.900
# 3             0.912            0.121           0.088     0.898  0.896
# 4             0.914            0.129           0.086     0.895  0.894
# 6             0.931            0.148           0.069     0.895  0.897
# 5             0.930            0.146           0.070     0.895  0.897
# 1             0.911            0.129           0.089     0.894  0.892
# 2             0.899            0.114           0.101     0.894  0.890
# 7             0.929            0.148           0.071     0.894  0.896
# 5             0.886            0.100           0.114     0.892  0.885
# 5             0.895            0.120           0.105     0.889  0.885
# 8             0.937            0.169           0.063     0.886  0.891
# 6             0.899            0.142           0.101     0.881  0.879
# 7             0.883            0.125           0.117     0.880  0.875
# 9             0.910            0.159           0.090     0.879  0.879
# 11            0.876            0.122           0.124     0.877  0.871
# 10            0.946            0.193           0.054     0.877  0.884
# 8             0.892            0.150           0.108     0.874  0.872
# 9             0.896            0.156           0.104     0.873  0.872
# 10            0.933            0.208           0.067     0.863  0.870
# 11            0.878            0.188           0.122     0.849  0.848
# 3             0.905            0.212           0.095     0.849  0.854
# 12            0.806            0.123           0.194     0.830  0.814
#
#     Precision  Recall     F1
# 0       0.927   0.915  0.921
# 1       0.909   0.926  0.917
# 3       0.904   0.928  0.916
# 2       0.911   0.918  0.915
# 0       0.898   0.914  0.906
# 4       0.891   0.924  0.908
# 1       0.879   0.923  0.901
# 0       0.882   0.912  0.897
# 1       0.898   0.890  0.894
# 0       0.861   0.925  0.892
# 2       0.880   0.898  0.889
# 2       0.891   0.878  0.885
# 3       0.873   0.900  0.887
# 4       0.870   0.902  0.886
# 3       0.879   0.884  0.882
# 4       0.871   0.887  0.879
# 6       0.852   0.914  0.882
# 5       0.854   0.911  0.881
# 1       0.871   0.883  0.877
# 2       0.886   0.864  0.875
# 7       0.852   0.910  0.880
# 5       0.900   0.841  0.869
# 5       0.880   0.857  0.869
# 8       0.831   0.923  0.875
# 6       0.858   0.866  0.862
# 7       0.875   0.840  0.857
# 9       0.841   0.884  0.862
# 11      0.878   0.827  0.852
# 10      0.807   0.936  0.867
# 8       0.850   0.857  0.854
# 9       0.844   0.865  0.854
# 10      0.792   0.922  0.852
# 11      0.812   0.843  0.827
# 3       0.788   0.886  0.834
# 12      0.877   0.703  0.780

# %%
# Best Performing Model #

Combined.drop("Unnamed: 0", axis = 1).sort_values("Accuracy", ascending = False).head(1)
# Out:
#               Name         Type  Share  True-Positives  False-Negatives  \
# 0  XLNet (Chinese)  Transformer  0.423           0.927            0.936
#
#    False-Positives  True-Negatives  Accuracy   AUC  Precision  Recall     F1
# 0            0.073           0.064     0.932  0.93      0.927   0.915  0.921

# %%
Combined.to_csv("./Output/All Model Performance Combined.csv")
